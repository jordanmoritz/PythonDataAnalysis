# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('example1.csv')
df1
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# Storing data aka 'serialization'
# Storing in pickle format is efficient binary data format
df1.to_pickle('example1pickle')

# %%
df2 = pd.read_pickle('example1pickle')
df2
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# %timeit df3 = pd.read_csv('example1.csv')
# %timeit df4 = pd.read_pickle('example1pickle')

# What's the point? Likely need larger examples
# Out:
# 774 µs ± 9.78 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 719 µs ± 7.26 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# HDF5 format
df5 = pd.DataFrame(np.random.randn(1000).reshape(100,10))
df5.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.048268 -0.967911 -1.343073  0.210339 -1.368793 -0.203314 -0.888114
# 1 -1.021363  2.717552  0.548198  0.743561  0.080105 -0.233037  0.681825
# 2  0.614111  0.181113  1.010557 -0.507362 -0.241034 -0.960660  1.554324
# 3  1.165002 -1.317819  1.840129  1.026588  0.458006 -0.130291 -0.306040
# 4 -1.427526 -0.667999 -2.173282 -1.476079 -0.305400  0.475612  1.327212
#
#           7         8         9
# 0  0.572396  0.228675 -0.176464
# 1 -0.277019  0.478360  0.430508
# 2 -0.325360 -1.148021  0.181351
# 3 -1.372339 -0.160801  1.161025
# 4 -1.241973 -0.585748  0.994934

# %%
store = pd.HDFStore('hdfexample.h5')
# Plops the file into HDF format and creates a reference to it
# I imagine out of memory?

store['obj1'] = df5

# %%
store['obj1_col'] = df5[1]

# %%
# Now I've stuck a bunch of other data structures inside the same HDF file
store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: hdfexample.h5

# %%
# You have options to store data with a 'table' schema that supports querying
store.put('obj2', df5, format='table')

# %%
store.select('obj2', where=['index >= 10 and index <= 15'])
# Out:
#            0         1         2         3         4         5         6  \
# 10  0.899943 -2.827862  1.262223  1.159096  0.266037 -1.242850 -0.282857
# 11  2.079771 -0.487494 -0.114317  0.166797  0.587891 -0.924623 -0.211763
# 12  0.048000  1.608390  0.514393  0.938207  0.118521  0.768140  1.909150
# 13  0.255644  0.957506  1.096865  0.139253 -2.157379  0.787281 -0.934788
# 14  0.818727 -1.722839  0.073789 -0.218033  1.084804 -2.409867  0.493685
# 15  0.381446 -0.956655  0.089791  0.150048  1.172030 -0.708701  1.845058
#
#            7         8         9
# 10  0.191495  0.333977  0.754115
# 11  0.147954 -2.870981  1.039374
# 12 -1.493587 -0.194870  0.276667
# 13  0.359257  1.181489 -0.568167
# 14  1.304990 -1.607220 -0.445040
# 15 -0.518008 -0.193112 -0.291310

# %%
df5.columns = ['a','b','c','d','e','f','g','h','i','j']

df5.head()
# Out:
#           a         b         c         d         e         f         g  \
# 0  1.048268 -0.967911 -1.343073  0.210339 -1.368793 -0.203314 -0.888114
# 1 -1.021363  2.717552  0.548198  0.743561  0.080105 -0.233037  0.681825
# 2  0.614111  0.181113  1.010557 -0.507362 -0.241034 -0.960660  1.554324
# 3  1.165002 -1.317819  1.840129  1.026588  0.458006 -0.130291 -0.306040
# 4 -1.427526 -0.667999 -2.173282 -1.476079 -0.305400  0.475612  1.327212
#
#           h         i         j
# 0  0.572396  0.228675 -0.176464
# 1 -0.277019  0.478360  0.430508
# 2 -0.325360 -1.148021  0.181351
# 3 -1.372339 -0.160801  1.161025
# 4 -1.241973 -0.585748  0.994934

# %%
store.put('obj3', df5, format='table')

# %%
store.select_column('obj3', column='a')
# store.select('obj3')

# Not working for whatever reason

# %%
store.close()

# %%
# Good 'ol Excel
excel_file = pd.ExcelFile('excel1.xlsx')

# %%
# Then just parse what you're looking
pd.read_excel(excel_file, 'Sheet1')
# Out:
#    'a'   'b'   'c'
# 0  '1'   '2'   '3'
# 1  '5'   '6'   '7'
# 2  '9'  '10'  '11'

# %%
# Other direction requires a writer object, like csv

excel_writer = pd.ExcelWriter('excel2.xlsx')

# %%
df5.to_excel(excel_writer, sheet_name='Sheet2')

excel_writer.close()
